# %% [markdown]
# # Limpieza y transformación de datos

# %% [markdown]
# ### CSV Customer Flight Activity

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_activity = pd.read_csv('files/Customer flight Activity.csv', index_col = 0)
df_activity.head()
# Out:
#                 Year  Month  Flights Booked  Flights with Companions  \
# Loyalty Number
# 100018          2017      1               3                        0
# 100102          2017      1              10                        4
# 100140          2017      1               6                        0
# 100214          2017      1               0                        0
# 100272          2017      1               0                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 100018                      3      1521               152.0                0
# 100102                     14      2030               203.0                0
# 100140                      6      1200               120.0                0
# 100214                      0         0                 0.0                0
# 100272                      0         0                 0.0                0
#
#                 Dollar Cost Points Redeemed
# Loyalty Number
# 100018                                    0
# 100102                                    0
# 100140                                    0
# 100214                                    0
# 100272                                    0

# %%
# unir columnas year-month

df_activity["date"] = pd.to_datetime(
    df_activity["Year"].astype(str) + "-" + df_activity["Month"].astype(str) + "-01"
)

# %%
columna = df_activity.pop("date")

# %%
df_activity.insert(2, "date", columna)

# %%
#Elimino columna Month
df_activity = df_activity.drop(columns="Month")

# %%
df_activity[df_activity.duplicated()]
# Out:
#                 Year       date  Flights Booked  Flights with Companions  \
# Loyalty Number
# 100272          2017 2017-01-01               0                        0
# 100301          2017 2017-01-01               0                        0
# 100364          2017 2017-01-01               0                        0
# 100380          2017 2017-01-01               0                        0
# 100504          2017 2017-01-01               0                        0
# ...              ...        ...             ...                      ...
# 999891          2018 2018-12-01               0                        0
# 999902          2018 2018-12-01               0                        0
# 999911          2018 2018-12-01               0                        0
# 999982          2018 2018-12-01               0                        0
# 999986          2018 2018-12-01               0                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 100272                      0         0                 0.0                0
# 100301                      0         0                 0.0                0
# 100364                      0         0                 0.0                0
# 100380                      0         0                 0.0                0
# 100504                      0         0                 0.0                0
# ...                       ...       ...                 ...              ...
# 999891                      0         0                 0.0                0
# 999902                      0         0                 0.0                0
# 999911                      0         0                 0.0                0
# 999982                      0         0                 0.0                0
# 999986                      0         0                 0.0                0
#
#                 Dollar Cost Points Redeemed
# Loyalty Number
# 100272                                    0
# 100301                                    0
# 100364                                    0
# 100380                                    0
# 100504                                    0
# ...                                     ...
# 999891                                    0
# 999902                                    0
# 999911                                    0
# 999982                                    0
# 999986                                    0
#
# [228705 rows x 9 columns]

# %%
df_activity
# Out:
#                 Year       date  Flights Booked  Flights with Companions  \
# Loyalty Number
# 100018          2017 2017-01-01               3                        0
# 100102          2017 2017-01-01              10                        4
# 100140          2017 2017-01-01               6                        0
# 100214          2017 2017-01-01               0                        0
# 100272          2017 2017-01-01               0                        0
# ...              ...        ...             ...                      ...
# 999902          2018 2018-12-01               0                        0
# 999911          2018 2018-12-01               0                        0
# 999940          2018 2018-12-01               3                        0
# 999982          2018 2018-12-01               0                        0
# 999986          2018 2018-12-01               0                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 100018                      3      1521               152.0                0
# 100102                     14      2030               203.0                0
# 100140                      6      1200               120.0                0
# 100214                      0         0                 0.0                0
# 100272                      0         0                 0.0                0
# ...                       ...       ...                 ...              ...
# 999902                      0         0                 0.0                0
# 999911                      0         0                 0.0                0
# 999940                      3      1233               123.0                0
# 999982                      0         0                 0.0                0
# 999986                      0         0                 0.0                0
#
#                 Dollar Cost Points Redeemed
# Loyalty Number
# 100018                                    0
# 100102                                    0
# 100140                                    0
# 100214                                    0
# 100272                                    0
# ...                                     ...
# 999902                                    0
# 999911                                    0
# 999940                                    0
# 999982                                    0
# 999986                                    0
#
# [405624 rows x 9 columns]

# %%
df_activity.isnull().sum() / len(df_activity) * 100
# Out:
# Year                           0.0
# date                           0.0
# Flights Booked                 0.0
# Flights with Companions        0.0
# Total Flights                  0.0
# Distance                       0.0
# Points Accumulated             0.0
# Points Redeemed                0.0
# Dollar Cost Points Redeemed    0.0
# dtype: float64

# %%
df_activity.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 405624 entries, 100018 to 999986
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Year                         405624 non-null  int64
#  1   date                         405624 non-null  datetime64[us]
#  2   Flights Booked               405624 non-null  int64
#  3   Flights with Companions      405624 non-null  int64
#  4   Total Flights                405624 non-null  int64
#  5   Distance                     405624 non-null  int64
#  6   Points Accumulated           405624 non-null  float64
#  7   Points Redeemed              405624 non-null  int64
#  8   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: datetime64[us](1), float64(1), int64(7)
# memory usage: 30.9 MB

# %% [markdown]
# ### CSV customer loyalty history

# %%
df_loyalty = pd.read_csv('files/Customer Loyalty History.csv', index_col = 0)
df_loyalty.head()
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario    Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta   Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia  Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario    Toronto     P1W 1K4    Male
# 530508          Canada            Quebec       Hull     J8Y 3Z5    Male
#
#                Education    Salary Marital Status Loyalty Card      CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0        Married         Star  3839.14
# 549612           College       NaN       Divorced         Star  3839.61
# 429460           College       NaN         Single         Star  3839.75
# 608370           College       NaN         Single         Star  3839.75
# 530508          Bachelor  103495.0        Married         Star  3842.79
#
#                Enrollment Type  Enrollment Year  Enrollment Month  \
# Loyalty Number
# 480934                Standard             2016                 2
# 549612                Standard             2016                 3
# 429460                Standard             2014                 7
# 608370                Standard             2013                 2
# 530508                Standard             2014                10
#
#                 Cancellation Year  Cancellation Month
# Loyalty Number
# 480934                        NaN                 NaN
# 549612                        NaN                 NaN
# 429460                     2018.0                 1.0
# 608370                        NaN                 NaN
# 530508                        NaN                 NaN

# %%
df_loyalty.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16737 entries, 480934 to 652627
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16737 non-null  str
#  1   Province            16737 non-null  str
#  2   City                16737 non-null  str
#  3   Postal Code         16737 non-null  str
#  4   Gender              16737 non-null  str
#  5   Education           16737 non-null  str
#  6   Salary              12499 non-null  float64
#  7   Marital Status      16737 non-null  str
#  8   Loyalty Card        16737 non-null  str
#  9   CLV                 16737 non-null  float64
#  10  Enrollment Type     16737 non-null  str
#  11  Enrollment Year     16737 non-null  int64
#  12  Enrollment Month    16737 non-null  int64
#  13  Cancellation Year   2067 non-null   float64
#  14  Cancellation Month  2067 non-null   float64
# dtypes: float64(4), int64(2), str(9)
# memory usage: 2.0 MB

# %%
#Comprobación de duplicados
df_loyalty.duplicated().sum()
# Out:
# np.int64(0)

# %%
# unir columnas enrollment year-month

df_loyalty["Enrollment Date"] = pd.to_datetime(
    df_loyalty["Enrollment Year"].astype(str) + "-" + df_loyalty["Enrollment Month"].astype(str) + "-01"
)

# %%
columna2 = df_loyalty.pop("Enrollment Date")
df_loyalty.insert(11, "Enrollment Date", columna2)

# %%
# unir columnas cancellation year-month

#primero las pasamos a int
columnas_cancellation = ['Cancellation Year', 'Cancellation Month']
df_loyalty[columnas_cancellation] = df_loyalty[columnas_cancellation].astype("Int64")

df_loyalty["Cancellation Date"] = pd.to_datetime(
    df_loyalty["Cancellation Year"].astype(str) + "-" + df_loyalty["Cancellation Month"].astype(str) + "-01"
)

# %%
#eliminar las columnas month

df_loyalty = df_loyalty.drop(columns=["Enrollment Month",'Cancellation Month'])

# %%
df_loyalty
# Out:
#                Country          Province        City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario     Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta    Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia   Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario     Toronto     P1W 1K4    Male
# 530508          Canada            Quebec        Hull     J8Y 3Z5    Male
# ...                ...               ...         ...         ...     ...
# 823768          Canada  British Columbia   Vancouver     V6E 3Z3  Female
# 680886          Canada      Saskatchewan      Regina     S1J 3C5  Female
# 776187          Canada  British Columbia   Vancouver     V5R 1W3    Male
# 906428          Canada             Yukon  Whitehorse     Y2K 6R0    Male
# 652627          Canada          Manitoba    Winnipeg     R2C 0M5  Female
#
#                Education    Salary Marital Status Loyalty Card       CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0        Married         Star   3839.14
# 549612           College       NaN       Divorced         Star   3839.61
# 429460           College       NaN         Single         Star   3839.75
# 608370           College       NaN         Single         Star   3839.75
# 530508          Bachelor  103495.0        Married         Star   3842.79
# ...                  ...       ...            ...          ...       ...
# 823768           College       NaN        Married         Star  61850.19
# 680886          Bachelor   89210.0        Married         Star  67907.27
# 776187           College       NaN         Single         Star  74228.52
# 906428          Bachelor  -57297.0        Married         Star  10018.66
# 652627          Bachelor   75049.0        Married         Star  83325.38
#
#                Enrollment Type Enrollment Date  Enrollment Year  \
# Loyalty Number
# 480934                Standard      2016-02-01             2016
# 549612                Standard      2016-03-01             2016
# 429460                Standard      2014-07-01             2014
# 608370                Standard      2013-02-01             2013
# 530508                Standard      2014-10-01             2014
# ...                        ...             ...              ...
# 823768                Standard      2012-12-01             2012
# 680886                Standard      2014-09-01             2014
# 776187                Standard      2014-03-01             2014
# 906428          2018 Promotion      2018-04-01             2018
# 652627                Standard      2015-12-01             2015
#
#                 Cancellation Year Cancellation Date
# Loyalty Number
# 480934                       <NA>               NaT
# 549612                       <NA>               NaT
# 429460                       2018        2018-01-01
# 608370                       <NA>               NaT
# 530508                       <NA>               NaT
# ...                           ...               ...
# 823768                       <NA>               NaT
# 680886                       <NA>               NaT
# 776187                       <NA>               NaT
# 906428                       <NA>               NaT
# 652627                       2016        2016-08-01
#
# [16737 rows x 15 columns]

# %% [markdown]
# #### Gestión de nulos salary

# %%
# Copia columna original

salary_original = df_loyalty["Salary"].copy()

# %%
#Antes de imputar los nulos, vemos la distribución

import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df_loyalty["Salary"], kde=True)

plt.title("Distribución del salario antes de imputar")
plt.xlabel("Salario")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
# En la visualización se observa que hay salarios negativos, por lo que serían valores nulos. 
# Se van a transformar a nulos, para luego imputar los valores


df_loyalty.loc[df_loyalty["Salary"] < 0, "Salary"] = np.nan

# %%
df_loyalty["Salary"].min()
# Out:
# np.float64(15609.0)

# %%
imputer_iter = IterativeImputer(max_iter=10, random_state=42) 
df_loyalty['Salary'] = imputer_iter.fit_transform(df_loyalty[['Salary']])

# %%
df_loyalty["Salary"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_loyalty["Salary"].value_counts().head(10)
# Out:
# Salary
# 79429.572642     4258
# 101933.000000      23
# 61809.000000       14
# 51573.000000       14
# 62283.000000       14
# 64001.000000       13
# 100159.000000      12
# 75827.000000       12
# 76159.000000       12
# 114551.000000      12
# Name: count, dtype: int64

# %%
sns.histplot(df_loyalty["Salary"], kde=True)

plt.title("Distribución del salario después de imputar")
plt.xlabel("Salario")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Unión de ambas tablas

# %%
print(f'Tamaño df_activity: {df_activity.shape}')
print(f'Tamaño df_loyalty: {df_loyalty.shape}')
# Out:
# Tamaño df_activity: (405624, 9)
# Tamaño df_loyalty: (16737, 15)

# %%
df_loyalty.index.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_activity.index.duplicated().sum()
# Out:
# np.int64(388887)

# %%
df_final = df_activity.merge(df_loyalty, on=['Loyalty Number'], how='left')
df_final.head()
# Out:
#                 Year       date  Flights Booked  Flights with Companions  \
# Loyalty Number
# 100018          2017 2017-01-01               3                        0
# 100102          2017 2017-01-01              10                        4
# 100140          2017 2017-01-01               6                        0
# 100214          2017 2017-01-01               0                        0
# 100272          2017 2017-01-01               0                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 100018                      3      1521               152.0                0
# 100102                     14      2030               203.0                0
# 100140                      6      1200               120.0                0
# 100214                      0         0                 0.0                0
# 100272                      0         0                 0.0                0
#
#                 Dollar Cost Points Redeemed Country  ... Education  \
# Loyalty Number                                       ...
# 100018                                    0  Canada  ...  Bachelor
# 100102                                    0  Canada  ...   College
# 100140                                    0  Canada  ...   College
# 100214                                    0  Canada  ...  Bachelor
# 100272                                    0  Canada  ...  Bachelor
#
#                       Salary Marital Status Loyalty Card      CLV  \
# Loyalty Number
# 100018          92552.000000        Married       Aurora  7919.20
# 100102          79429.572642         Single         Nova  2887.74
# 100140          79429.572642       Divorced         Nova  2838.07
# 100214          63253.000000        Married         Star  4170.57
# 100272          91163.000000       Divorced         Star  6622.05
#
#                 Enrollment Type Enrollment Date Enrollment Year  \
# Loyalty Number
# 100018                 Standard      2016-08-01            2016
# 100102                 Standard      2013-03-01            2013
# 100140                 Standard      2016-07-01            2016
# 100214                 Standard      2015-08-01            2015
# 100272                 Standard      2014-01-01            2014
#
#                 Cancellation Year Cancellation Date
# Loyalty Number
# 100018                       <NA>               NaT
# 100102                       <NA>               NaT
# 100140                       <NA>               NaT
# 100214                       <NA>               NaT
# 100272                       <NA>               NaT
#
# [5 rows x 24 columns]

# %%
#Unificación nombre columnas

df_final.columns = (
    df_final.columns
    .str.lower()
    .str.replace(" ", "_")
)
df_final.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 405624 entries, 100018 to 999986
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   year                         405624 non-null  int64
#  1   date                         405624 non-null  datetime64[us]
#  2   flights_booked               405624 non-null  int64
#  3   flights_with_companions      405624 non-null  int64
#  4   total_flights                405624 non-null  int64
#  5   distance                     405624 non-null  int64
#  6   points_accumulated           405624 non-null  float64
#  7   points_redeemed              405624 non-null  int64
#  8   dollar_cost_points_redeemed  405624 non-null  int64
#  9   country                      405624 non-null  str
#  10  province                     405624 non-null  str
#  11  city                         405624 non-null  str
#  12  postal_code                  405624 non-null  str
#  13  gender                       405624 non-null  str
#  14  education                    405624 non-null  str
#  15  salary                       405624 non-null  float64
#  16  marital_status               405624 non-null  str
#  17  loyalty_card                 405624 non-null  str
#  18  clv                          405624 non-null  float64
#  19  enrollment_type              405624 non-null  str
#  20  enrollment_date              405624 non-null  datetime64[us]
#  21  enrollment_year              405624 non-null  int64
#  22  cancellation_year            50064 non-null   Int64
#  23  cancellation_date            50064 non-null   datetime64[us]
# dtypes: Int64(1), datetime64[us](3), float64(3), int64(8), str(9)
# memory usage: 77.8 MB

# %% [markdown]
# ## Gestión de nulos

# %%
df_final.isnull().sum()/len(df_final) * 100
# Out:
# year                            0.000000
# date                            0.000000
# flights_booked                  0.000000
# flights_with_companions         0.000000
# total_flights                   0.000000
# distance                        0.000000
# points_accumulated              0.000000
# points_redeemed                 0.000000
# dollar_cost_points_redeemed     0.000000
# country                         0.000000
# province                        0.000000
# city                            0.000000
# postal_code                     0.000000
# gender                          0.000000
# education                       0.000000
# salary                          0.000000
# marital_status                  0.000000
# loyalty_card                    0.000000
# clv                             0.000000
# enrollment_type                 0.000000
# enrollment_date                 0.000000
# enrollment_year                 0.000000
# cancellation_year              87.657535
# cancellation_date              87.657535
# dtype: float64

# %%
# Es probable que haya nulos en la fecha de cancelación porque esos clientes no han cancelado su membresía
# Por ello ni se borran ni se imputan. Creo una nueva columna que indica si ha cancelado o no

df_final["is_cancelled"] = df_final["cancellation_date"].notnull()

# %%
df_final
# Out:
#                 year       date  flights_booked  flights_with_companions  \
# Loyalty Number
# 100018          2017 2017-01-01               3                        0
# 100102          2017 2017-01-01              10                        4
# 100140          2017 2017-01-01               6                        0
# 100214          2017 2017-01-01               0                        0
# 100272          2017 2017-01-01               0                        0
# ...              ...        ...             ...                      ...
# 999902          2018 2018-12-01               0                        0
# 999911          2018 2018-12-01               0                        0
# 999940          2018 2018-12-01               3                        0
# 999982          2018 2018-12-01               0                        0
# 999986          2018 2018-12-01               0                        0
#
#                 total_flights  distance  points_accumulated  points_redeemed  \
# Loyalty Number
# 100018                      3      1521               152.0                0
# 100102                     14      2030               203.0                0
# 100140                      6      1200               120.0                0
# 100214                      0         0                 0.0                0
# 100272                      0         0                 0.0                0
# ...                       ...       ...                 ...              ...
# 999902                      0         0                 0.0                0
# 999911                      0         0                 0.0                0
# 999940                      3      1233               123.0                0
# 999982                      0         0                 0.0                0
# 999986                      0         0                 0.0                0
#
#                 dollar_cost_points_redeemed country  ...         salary  \
# Loyalty Number                                       ...
# 100018                                    0  Canada  ...   92552.000000
# 100102                                    0  Canada  ...   79429.572642
# 100140                                    0  Canada  ...   79429.572642
# 100214                                    0  Canada  ...   63253.000000
# 100272                                    0  Canada  ...   91163.000000
# ...                                     ...     ...  ...            ...
# 999902                                    0  Canada  ...   79429.572642
# 999911                                    0  Canada  ...  217943.000000
# 999940                                    0  Canada  ...   47670.000000
# 999982                                    0  Canada  ...   79429.572642
# 999986                                    0  Canada  ...   46594.000000
#
#                marital_status loyalty_card       clv enrollment_type  \
# Loyalty Number
# 100018                Married       Aurora   7919.20        Standard
# 100102                 Single         Nova   2887.74        Standard
# 100140               Divorced         Nova   2838.07        Standard
# 100214                Married         Star   4170.57        Standard
# 100272               Divorced         Star   6622.05        Standard
# ...                       ...          ...       ...             ...
# 999902                Married       Aurora   7290.07        Standard
# 999911                 Single         Nova   8564.77        Standard
# 999940                Married         Nova  20266.50        Standard
# 999982                Married         Star   2631.56        Standard
# 999986                Married         Nova   8257.01  2018 Promotion
#
#                 enrollment_date enrollment_year cancellation_year  \
# Loyalty Number
# 100018               2016-08-01            2016              <NA>
# 100102               2013-03-01            2013              <NA>
# 100140               2016-07-01            2016              <NA>
# 100214               2015-08-01            2015              <NA>
# 100272               2014-01-01            2014              <NA>
# ...                         ...             ...               ...
# 999902               2014-05-01            2014              <NA>
# 999911               2012-08-01            2012              <NA>
# 999940               2017-07-01            2017              <NA>
# 999982               2018-07-01            2018              <NA>
# 999986               2018-02-01            2018              <NA>
#
#                 cancellation_date is_cancelled
# Loyalty Number
# 100018                        NaT        False
# 100102                        NaT        False
# 100140                        NaT        False
# 100214                        NaT        False
# 100272                        NaT        False
# ...                           ...          ...
# 999902                        NaT        False
# 999911                        NaT        False
# 999940                        NaT        False
# 999982                        NaT        False
# 999986                        NaT        False
#
# [405624 rows x 25 columns]

# %%
#Como el % nulos en salario supera el 20%, usamos algoritmos para imputar los nulos.
#Se hace en el apartado de la tabla loyalty, para imputar los nulos antes de unificar las tablas. Dado que como en la tabla df_activity hay duplicados, podría distorsionar la imputación

df_final.isnull().sum()/len(df_final) * 100
# Out:
# year                            0.000000
# date                            0.000000
# flights_booked                  0.000000
# flights_with_companions         0.000000
# total_flights                   0.000000
# distance                        0.000000
# points_accumulated              0.000000
# points_redeemed                 0.000000
# dollar_cost_points_redeemed     0.000000
# country                         0.000000
# province                        0.000000
# city                            0.000000
# postal_code                     0.000000
# gender                          0.000000
# education                       0.000000
# salary                          0.000000
# marital_status                  0.000000
# loyalty_card                    0.000000
# clv                             0.000000
# enrollment_type                 0.000000
# enrollment_date                 0.000000
# enrollment_year                 0.000000
# cancellation_year              87.657535
# cancellation_date              87.657535
# is_cancelled                    0.000000
# dtype: float64

# %% [markdown]
# ### Limpieza variables categóricas

# %%
df_final['province'].unique()
# Out:
# <StringArray>
# [             'Alberta',              'Ontario',     'British Columbia',
#          'Saskatchewan',               'Quebec',         'Newfoundland',
#              'Manitoba',        'New Brunswick',          'Nova Scotia',
#  'Prince Edward Island',                'Yukon']
# Length: 11, dtype: str

# %%
df_final['country'].unique()
# Out:
# <StringArray>
# ['Canada']
# Length: 1, dtype: str

# %%
df_final['city'].unique()
# Out:
# <StringArray>
# [      'Edmonton',        'Toronto',   'Dawson Creek',      'Vancouver',
#          'Regina',       'Montreal',        'Sudbury',    'Quebec City',
#     'Peace River',     'St. John's',      'Tremblant',         'Ottawa',
#         'Trenton',       'Winnipeg',    'Thunder Bay', 'West Vancouver',
#     'Fredericton',         'London',        'Halifax',        'Moncton',
#           'Banff',       'Kingston',       'Whistler',  'Charlottetown',
#            'Hull',       'Victoria',        'Calgary',        'Kelowna',
#      'Whitehorse']
# Length: 29, dtype: str

# %%
df_final['postal_code'].unique()
# Out:
# <StringArray>
# ['T9G 1W3', 'M1R 4K3', 'U5I 4F1', 'V5R 1W3', 'P1L 8X8', 'P1J 8T7', 'S6J 3G0',
#  'H2T 9K8', 'V6E 3D9', 'M5V 1G5', 'H2Y 4R4', 'M8Y 4K8', 'V6E 3Z3', 'G1B 3L5',
#  'T9O 2W2', 'A1C 6H9', 'H5Y 2S9', 'K1F 2R2', 'K8V 4B2', 'R3R 3T4', 'P1W 1K4',
#  'K8T 5M5', 'V6V 8Z3', 'M2M 7K8', 'E3B 2H2', 'M5B 3E4', 'H2Y 2W2', 'P5S 6R4',
#  'P2T 6G3', 'B3J 9S2', 'B3C 2M8', 'H4G 3T4', 'R6Y 4T5', 'H2T 2J6', 'M2Z 4K1',
#  'S1J 3C5', 'E1A 2A7', 'V1E 4R6', 'T4V 1D4', 'M9K 2P4', 'R2C 0M5', 'T3G 6Y6',
#  'M2M 6J7', 'V6T 1Y8', 'C1A 6E8', 'J8Y 3Z5', 'V10 6T5', 'H3T 8L4', 'T3E 2V9',
#  'V09 2E9', 'Y2K 6R0', 'K1G 4Z0', 'M2P 4F6', 'M3R 4K8', 'H3J 5I6']
# Length: 55, dtype: str

# %%
df_final['gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df_final['education'].unique()
# Out:
# <StringArray>
# ['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor']
# Length: 5, dtype: str

# %%
df_final['marital_status'].unique()
# Out:
# <StringArray>
# ['Married', 'Single', 'Divorced']
# Length: 3, dtype: str

# %%
df_final['loyalty_card'].unique()
# Out:
# <StringArray>
# ['Aurora', 'Nova', 'Star']
# Length: 3, dtype: str

# %%
df_final['enrollment_type'].unique()
# Out:
# <StringArray>
# ['Standard', '2018 Promotion']
# Length: 2, dtype: str

# %%
df_final.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 405624 entries, 100018 to 999986
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   year                         405624 non-null  int64
#  1   date                         405624 non-null  datetime64[us]
#  2   flights_booked               405624 non-null  int64
#  3   flights_with_companions      405624 non-null  int64
#  4   total_flights                405624 non-null  int64
#  5   distance                     405624 non-null  int64
#  6   points_accumulated           405624 non-null  float64
#  7   points_redeemed              405624 non-null  int64
#  8   dollar_cost_points_redeemed  405624 non-null  int64
#  9   country                      405624 non-null  str
#  10  province                     405624 non-null  str
#  11  city                         405624 non-null  str
#  12  postal_code                  405624 non-null  str
#  13  gender                       405624 non-null  str
#  14  education                    405624 non-null  str
#  15  salary                       405624 non-null  float64
#  16  marital_status               405624 non-null  str
#  17  loyalty_card                 405624 non-null  str
#  18  clv                          405624 non-null  float64
#  19  enrollment_type              405624 non-null  str
#  20  enrollment_date              405624 non-null  datetime64[us]
#  21  enrollment_year              405624 non-null  int64
#  22  cancellation_year            50064 non-null   Int64
#  23  cancellation_date            50064 non-null   datetime64[us]
#  24  is_cancelled                 405624 non-null  bool
# dtypes: Int64(1), bool(1), datetime64[us](3), float64(3), int64(8), str(9)
# memory usage: 78.1 MB

# %%
df_final.index
# Out:
# Index([100018, 100102, 100140, 100214, 100272, 100301, 100364, 100380, 100428,
#        100504,
#        ...
#        999631, 999891, 999758, 999891, 999891, 999902, 999911, 999940, 999982,
#        999986],
#       dtype='int64', name='Loyalty Number', length=405624)

# %% [markdown]
# ## Guardado tabla final

# %%
df_final.to_csv("df_final_limpio.csv")
